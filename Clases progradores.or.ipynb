# %%
spark.sql("select 1").show()

# %%
JDBC_URL = "jdbc:postgresql://104.196.54.170:5432/postgres" 
PROPERTIES = {
    "user": "postgres",
    "password": "Super123456!",
    "driver": "org.postgresql.Driver"
}

# %%
df_jdbc = spark.read.jdbc(url=JDBC_URL, table="\"public\".\"Sales\"", properties=PROPERTIES)

# %%
display(df_jdbc)

# %%
df_jdbc.createOrReplaceTempView("tmp_sales")

# %%
# %sql

--select * from tmp_jdbc
create external table if not exists unity_catalog.lab.sales
using DELTA
location 'abfss://raw@cs2100320032141b0ad.dfs.core.windows.net/lab/sales' as
select * from tmp_sales

# %%
# %sql

select * from unity_catalog.lab.sales;
# Out:
# Databricks visualization. Run in Databricks to view.
# Databricks visualization. Run in Databricks to view.
